# %%
from ultralytics import YOLO

model = YOLO("/home/anawat/JJ/Chula/Chess2PGN/weights/corner/corner-detect.pt")

# %%
result = model("/home/anawat/JJ/Chula/Chess2PGN/data/test/chess3.png")
# Out:
# image 1/1 /home/anawat/JJ/Chula/Chess2PGN/data/test/chess3.png: 416x416 1 bottom-left, 3 bottom-rights, 2 top-rights, 208.4ms
# Speed: 1.4ms preprocess, 208.4ms inference, 7.8ms postprocess per image at shape (1, 3, 416, 416)

# %%
result[0].show()
