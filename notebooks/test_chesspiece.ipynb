# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("/home/anawat/JJ/Chula/Chess2PGN/data/test/chess4.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img = cv2.rotate(img, cv2.ROTATE_180)
img = cv2.resize(img, (512, 512), interpolation=cv2.INTER_LINEAR)

plt.figure(figsize=(5, 5))
plt.imshow(img)

# %%
model = YOLO("/home/anawat/JJ/Chula/Chess2PGN/weights/chess-piece/best(4).pt")

# %%
result = model(img)

result[0].show()
# Out:
# 0: 640x640 2 black-bishops, 1 black-king, 2 black-knights, 6 black-pawns, 1 black-queen, 1 black-rook, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 2 white-queens, 2 white-rooks, 379.2ms
# Speed: 2.2ms preprocess, 379.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
print(model.names)
# Out:
# {0: 'black-bishop', 1: 'black-king', 2: 'black-knight', 3: 'black-pawn', 4: 'black-queen', 5: 'black-rook', 6: 'white-bishop', 7: 'white-king', 8: 'white-knight', 9: 'white-pawn', 10: 'white-queen', 11: 'white-rook'}
